# %% [markdown]
# ## Chain Rule
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Computational Graph
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Steps of Backpropagation
# #### 1) Forward Pass
#     - This is where we compute loss
# #### 2) Compute Local Gradients
#     - Calculate the local gradients, that is, the gradients at each node.
# #### 3) Backward Pass
#     - This is where we compute dLoss/dWeights using chain rule.

# %% [markdown]
# ### Example:
#     Let us say we have training samples x=1, y=2 and w=1.
